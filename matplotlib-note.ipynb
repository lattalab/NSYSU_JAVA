# %%
#it is a note to matplotlib
import matplotlib.pyplot as plt
#用plt.show() 印出圖表
#使用 matplotlib 繪製圖表時，可以透過設定 figure 的參數，
#設定畫布的尺寸 ( 改變圖表尺寸 )、邊框或底色

#The subplot() function takes three arguments that describes the layout of the figure.
#1st argv = row , 2nd argv = columes , 3rd argv = position

#折線圖:    plt.plot(x,y)
#plt.plot([1,2,3,4,5],[10,11,12,13,14],"o")
#加個o ， 會變成印出點
#如果不傳入x的值，會有預設值
#Hint: 標記參考(點要用什麼表示)
#marker = "o" ，折線圖 +　印出點
#也可以用星星符號代表點，marker = "*"
#也有 線參考 、 線的顏色
#快速指派: marker:line:color
# ex. plt.plot(ypoints , 'o:r')
#marker的size跟color可以改變

#為x軸跟y軸設立標籤 : plt.xlabel() , plt.ylabel()
#標題: plt.title() ，用loc可以移動標題位置
#plt.grid() : 圖背後印出網格線，還有一些變數調整格式

#散佈圖     plt.scatter(x,y)
#柱狀圖     plt.bar(x,y)
#水平柱狀圖 plt.barh(x,y)
#直方圖     plt.hist(x,y) #直方圖最適合用圖形表示具有連續資料範圍的數值變數
#圓餅圖     plt.pie(x,y)
